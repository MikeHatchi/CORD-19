# %% [markdown]
# # COVID-19 Open Research Dataset Challenge (CORD-19)
# An AI challenge with AI2, CZI, MSR, Georgetown, NIH & The White House
#
# ### Task: What do we know about COVID-19 risk factors?

# %% [markdown]
# ---

# %% [markdown]
# ### Information about the data

# %% [markdown]
# 1. Metadata for papers from these sources are combined: CZI, PMC, BioRxiv/MedRxiv. (total records 29500)
#     - CZI 1236 records
#     - PMC 27337
#     - bioRxiv 566
#     - medRxiv 361
# 2. 17K of the paper records have PDFs and the hash of the PDFs are in 'sha'<br>
# 3. For PMC sourced papers, one paper's metadata can be associated with one or more PDFs/shas under that paper - a PDF/sha correponding to the main article, and possibly additional PDF/shas corresponding to supporting materials for the article.<br>
# 4. 13K of the PDFs were processed with fulltext ('has_full_text'=True)<br>
# 5. Various 'keys' are populated with the metadata:
#     - 'pmcid': populated for all PMC paper records (27337 non null)
# 	- 'doi': populated for all BioRxiv/MedRxiv paper records and most of the other records (26357 non null)
# 	- 'WHO #Covidence': populated for all CZI records and none of the other records (1236 non null)
# 	- 'pubmed_id': populated for some of the records
# 	- 'Microsoft Academic Paper ID': populated for some of the records

# %% [markdown]
# **Chan Zuckerberg Initiative (CZI)**<br>
# **PubMed Central (PMC)** is a free digital repository that archives publicly accessible full-text scholarly articles that have been published within the biomedical and life sciences journal literature.<br>
# **BioRxiv** (pronounced "bio-archive") is an open access preprint repository for the biological sciences<br>
# **medRxiv. medRxiv** (pronounced med archive) is a preprint service for the medicine and health sciences and provides a free online platform for researchers to share, comment, and receive feedback on their work. Information among scientists spreads slowly, and often incompletely.

# %% [markdown]
# ---

# %% [markdown]
# # Themes

# %% [markdown]
# ## Transform the required themes

# %%
import pandas as pd
from io import StringIO

# %% [markdown]
# ### Initial form of themes:
# > 1. Data on potential risks factors
#     - Smoking, pre-existing pulmonary disease
#     - Co-infections (determine whether co-existing respiratory/viral infections make the virus more transmissible or virulent) and other co-morbidities
#     - Neonates and pregnant women
#     - Socio-economic and behavioral factors to understand the economic impact of the virus and whether there were differences.
# 2. Transmission dynamics of the virus, including the basic reproductive number, incubation period, serial interval, modes of transmission and environmental factors
# 3. Severity of disease, including risk of fatality among symptomatic hospitalized patients, and high-risk patient groups
# 4. Susceptibility of populations
# 5. Public health mitigation measures that could be effective for control

# %%
riskfac = StringIO("""Factor;Description
    Pulmorary risk;Smoking, preexisting pulmonary disease
    Infection risk;Coinfections determine whether coexisting respiratory or viral infections make the virus more transmissible or virulent and other comorbidities
    Birth risk;Neonates and pregnant women
    Socio-economic risk;Socio-economic and behavioral factors to understand the economic impact of the virus and whether there were differences
    Transmission;Transmission dynamics of the virus, including the basic reproductive number, incubation period, serial interval, modes of transmission and environmental factors
    Severity;Severity of disease, including risk of fatality among symptomatic hospitalized patients, and high-risk patient groups
    Susceptibility;Susceptibility of populations
    mitig measures;Public health mitigation measures that could be effective for control
    """)

rf_base = pd.read_csv(riskfac, sep= ";")
rf_base
# Out:
#                     Factor                                        Description
# 0           Pulmorary risk             Smoking, preexisting pulmonary disease
# 1           Infection risk  Coinfections determine whether coexisting resp...
# 2               Birth risk                        Neonates and pregnant women
# 3      Socio-economic risk  Socio-economic and behavioral factors to under...
# 4             Transmission  Transmission dynamics of the virus, including ...
# 5                 Severity  Severity of disease, including risk of fatalit...
# 6           Susceptibility                      Susceptibility of populations
# 7           mitig measures  Public health mitigation measures that could b...

# %%
# exporting factors and description to save it.
rf_base.to_csv(r'2020-03-13/rf_base.csv', index = False)

# %%
import spacy

# %%
nlp = spacy.load('en_core_web_sm')

from spacy.matcher import Matcher
m_tool = Matcher(nlp.vocab)

# %% [markdown]
# ## Load the themes

# %%
data = pd.read_csv('2020-03-13/rf_base.csv', delimiter=',', header=None, skiprows=1, names=['Factor','Description'])
# We only need the Headlines text column from the data
descp = data[:8][['Description']];
descp['index'] = descp.index

# %%
descp
# Out:
#                                          Description  index
# 0             Smoking, preexisting pulmonary disease      0
# 1  Coinfections determine whether coexisting resp...      1
# 2                        Neonates and pregnant women      2
# 3  Socio-economic and behavioral factors to under...      3
# 4  Transmission dynamics of the virus, including ...      4
# 5  Severity of disease, including risk of fatalit...      5
# 6                      Susceptibility of populations      6
# 7  Public health mitigation measures that could b...      7

# %% [markdown]
# ## Preprocess the themes

# %%
# Loading Gensim and nltk libraries

import gensim
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.stem.porter import *
import numpy as np
np.random.seed(400)
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/mikehatchi/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# a function for preprocessing text
"""
def lemmatize_stemming(text):
    stemmer = SnowballStemmer('english')
    return stemmer.stem(WordNetLemmatizer().lemmatize(text, pos='v'))
"""
def preprocess(text):
    result=[]
    for token in gensim.utils.simple_preprocess(text) :
        if token not in gensim.parsing.preprocessing.STOPWORDS and len(token) > 3:
            # result.append(lemmatize_stemming(token))
            result.append(token)
    return result

# %%
'''
Preview a document after preprocessing
'''
theme_num = 0
theme_sample = descp[descp['index'] == theme_num].values[0][0]

print("Original document: ")
words = []
for word in theme_sample.split(' '):
    words.append(word)
print(words)
print("\n\nTokenized and lemmatized document: ")
print(preprocess(theme_sample))
# Out:
# Original document:
# ['Smoking,', 'preexisting', 'pulmonary', 'disease']
#
#
# Tokenized and lemmatized document:
# ['smoking', 'preexisting', 'pulmonary', 'disease']

# %%
# descp = descp.dropna(subset=['Description'])
processed_docs = descp['Description'].map(preprocess)
# [processed_docs[i] for i in range(8)]

# %% [markdown]
# ## Feature extraction

# %% [markdown]
# ### Binary Encoding

# %%
factor = []
for i in processed_docs[:8]:
    vocab = set(i)
    factor.append(vocab)

for i in range(8):
    print(len(factor[i]), factor[i])
# Out:
# 4 {'disease', 'smoking', 'pulmonary', 'preexisting'}
# 10 {'infections', 'transmissible', 'respiratory', 'coexisting', 'virus', 'determine', 'comorbidities', 'virulent', 'coinfections', 'viral'}
# 3 {'pregnant', 'neonates', 'women'}
# 8 {'economic', 'behavioral', 'virus', 'socio', 'impact', 'understand', 'factors', 'differences'}
# 14 {'basic', 'period', 'reproductive', 'transmission', 'serial', 'dynamics', 'number', 'environmental', 'virus', 'interval', 'modes', 'including', 'factors', 'incubation'}
# 11 {'high', 'fatality', 'disease', 'severity', 'patient', 'hospitalized', 'including', 'groups', 'risk', 'symptomatic', 'patients'}
# 2 {'populations', 'susceptibility'}
# 6 {'mitigation', 'health', 'effective', 'public', 'measures', 'control'}

# %% [markdown]
# ---

# %% [markdown]
# # Retrieve Metadata data
# sha / source_x / title / doi / pmcid / pubmed_id / authors / journal / Microsot A.P ID / Who # covidence

# %%
data = pd.read_csv("2020-03-13/all_sources_metadata_2020-03-13.csv")

# %%
def met_xiv(data, sha):
    for i, tracksha in data['sha']:
        if tracksha == sha:
            print("sha: {} - Source X: {} \n\nTitle:\n{} \n\ndoi:\n{} \n\npmcid:{} - pubmed_id:{} \n\nauthors:\n{} \n\journal:\n{} - Microsoft Academic Paper ID:{} - WHO #Covidence: {}".format(data['sha'],
                                                                                                                                                                                                 data['source_x'],
                                                                                                                                                                                                 data['title'],
                                                                                                                                                                                                 data['doi'],
                                                                                                                                                                                                 data['pmcid'],
                                                                                                                                                                                                 data['pubmed_id'],
                                                                                                                                                                                                 data['authors'],
                                                                                                                                                                                                 data['journal'],
                                                                                                                                                                                                 data['Microsoft Academic Paper ID'],
                                                                                                                                                                                                 data['WHO #Covidence']))

# %%
sha = 'c630ebcdf30652f0422c3ec12a00b50241dc9bd9'
met_xiv(data, sha)
# Out:
# sha: 0        c630ebcdf30652f0422c3ec12a00b50241dc9bd9
# 1        53eccda7977a31e3d0f565c884da036b1e85438e
# 2        210a892deb1c61577f6fba58505fd65356ce6636
# 3        e3b40cc8e0e137c416b4a2273a4dca94ae8178cc
# 4        92c2c9839304b4f2bc1276d41b1aa885d8b364fd
# 5        0df0d5270a9399cf4e23c0cdd877a80616a9725e
# 6        f24242580be243d5fc3f432915d86af6854bb8b7
# 7        d13a685f861b0f1ba05afa6e005311ad1820fd3a
# 8        e1b336d8be1a4c0ccc5a1bf41e48b3b004d3ece1
# 9        e9239100c5493ea914dc23c3d7a262f4326022ac
# 10       469ed0f00c09e2637351c9735c306f27acf3aace
# 11       4e550e034ccca6fa2a91e481ddba24db67bc9ae5
# 12       4bbb0c59babc718f67953fae032dad6ae0d7aeb1
# 13       c821803c55c6aad89b6d0c1d3ba252051e464017
# 14       c3bee2a4caca614b34f92c17b643b854dcdab28d
# 15       715842fa536064980818ad7e31ce511272a4b6bc
# 16       601d3c7ae4ebcd2d835e9cf8d7427ebd0b5db83f
# 17       06c89f69aa7b5f9648d2c1543b8246fe9c3610cf
# 18       acb678bdd7634055de18d0b89bb6a4890e6a0306
# 19       47772f3e98d8c61bb9782531a0338ba85f27bf3f
# 20       544a170a18bae9bf44c531c2b0b4bdc5e85ea8f5
# 21       4ff89a71126d2932544a8337ba28787fde5f02a8
# 22       ac37ba61c91bb6939a507dbf4efe2119ddafeb9c
# 23       6dfe2e77c8175b3eb38d6fc3ccc440fb81a0e2f0
# 24       c9fee561c2a3834645dbb61dc4ae6448051da492
# 25       655537fc8cc52bccf43cf7189ab060d3097caa7a
# 26       bb7cd48a85b72f8d73e57d655c6d8a034fce3778
# 27       3c42431c5b95e707486ce7441ac139071e07b706
# 28       6a93283b499ae5bc6aaf29f14e701dc8f25138ea
# 29       6fc52ed878c271020a2a375bb6e4b12943a7666c
#                            ...
# 29470    083dd400b7854ffa908a21641197855aee981ea5
# 29471    93d8f1552a81587e2f88e38580cbe4753b9934f1
# 29472    dd2cd004a197872cfce1c31a9685d6972f838efa
# 29473    e53f5a6c4cbac340f0d97a4ba3289c30b7222dd5
# 29474    fd847a97e6fce134345b25ae9240c4ebb680cca5
# 29475    610549c879c62efc42f2ad32f63c65b25d8931c7
# 29476    088d5c4a4f212be9590b6ce3d70a8e01847e76cf
# 29477    fd96fc1859201e13e35526c188e022fa6e335327
# 29478    26e75d3c815aae7fd9b094c3e5c74d3f7132ca13
# 29479    bd08e2cbbc561e52823aedd0180f844e0c6cd2a6
# 29480    ea17aad7692bb5040f3b2ba1d01b8249e4969469
# 29481    6d3b3f4ab80a61c45f82c61c6c756cfc6ddf4bf2
# 29482    3ba79e5d013c7c3cccd1449ccd16b93c61a4c576
# 29483    c1a08ce8f2c5d5311b19822c3df5aa9d25c4d93c
# 29484    c6012a6141f5ad05ac983aa9f1a7c57938363b16
# 29485    74bee8bf3229f4c28991a7231c02d911d24770e9
# 29486    ec90b0b861d31f910433d388370344024ca7c35d
# 29487    970a28c4a3c1fbcb5322772956955b8c4a3bb257
# 29488    abe590b95aa51e7309844156acdae4085870ea33
# 29489    9a077c5ff1dcbb9104feeaa832e73ccdcf5fdcc9
# 29490    6cf87a546884756094da0d300e85a061c2cc43ea
# 29491    43f760b5cb9c3b430c6d0b31fa90d42e71a6429c
# 29492    901572f1595cb6ea733858d3fc15b8ea46054061
# 29493    4c84d1153daa335f5ff6d61db665024b32ac8195
# 29494    e5f19b6daf956e815c779228cc0cad1293d65bbb
# 29495    c42a617a00afe6a36bde0a8e3638e0f55bfee4f7
# 29496    c4ce14ce42fa4360dfe3515ec9d1584847381c27
# 29497    c41e09a32be90c84cea0616bb1c726aecba721e0
# 29498    ca88735399ff43d0e673876200655099f06f5567
# 29499    0b48e1bfcdff9a42c88cc80a98661feb2703390d
# Name: sha, Length: 29500, dtype: object - Source X: 0            CZI
# 1            CZI
# 2            CZI
# 3            CZI
# 4            CZI
# 5            CZI
# 6            CZI
# 7            CZI
# 8            CZI
# 9            CZI
# 10           CZI
# 11           CZI
# 12           CZI
# 13           CZI
# 14           CZI
# 15           CZI
# 16           CZI
# 17           CZI
# 18           CZI
# 19           CZI
# 20           CZI
# 21           CZI
# 22           CZI
# 23           CZI
# 24           CZI
# 25           CZI
# 26           CZI
# 27           CZI
# 28           CZI
# 29           CZI
#           ...
# 29470    medrxiv
# 29471    medrxiv
# 29472    medrxiv
# 29473    medrxiv
# 29474    medrxiv
# 29475    medrxiv
# 29476    medrxiv
# 29477    medrxiv
# 29478    medrxiv
# 29479    medrxiv
# 29480    medrxiv
# 29481    medrxiv
# 29482    medrxiv
# 29483    medrxiv
# 29484    medrxiv
# 29485    medrxiv
# 29486    medrxiv
# 29487    medrxiv
# 29488    medrxiv
# 29489    medrxiv
# 29490    medrxiv
# 29491    medrxiv
# 29492    medrxiv
# 29493    medrxiv
# 29494    medrxiv
# 29495    medrxiv
# 29496    medrxiv
# 29497    medrxiv
# 29498    medrxiv
# 29499    medrxiv
# Name: source_x, Length: 29500, dtype: object
#
# Title:
# 0        Angiotensin-converting enzyme 2 (ACE2) as a SA...
# 1        Comparative genetic analysis of the novel coro...
# 2        Incubation Period and Other Epidemiological Ch...
# 3        Characteristics of and Public Health Responses...
# 4             Imaging changes in severe COVID-19 pneumonia
# 5        An updated estimation of the risk of transmiss...
# 6        Real-time forecasts of the 2019-nCoV epidemic ...
# 7        RETRACTED: Chinese medical staff request inter...
# 8        COVID-19 outbreak on the Diamond Princess crui...
# 9        Distinct Roles for Sialoside and Protein Recep...
# 10       First two months of the 2019 Coronavirus Disea...
# 11       Effectiveness of airport screening at detectin...
# 12       Genome Detective Coronavirus Typing Tool for r...
# 13       Case of the Index Patient Who Caused Tertiary ...
# 14       Emergence of Novel Coronavirus 2019-nCoV: Need...
# 15       The coronavirus 2019-nCoV epidemic: Is hindsig...
# 16       Nonstructural proteins NS7b and NS8 are likely...
# 17       Pathogenicity and Transmissibility of 2019-nCo...
# 18       Remdesivir and chloroquine effectively inhibit...
# 19       Potential for global spread of a novel coronav...
# 20       Severe acute respiratory symptoms and suspecte...
# 21       Statistics-Based Predictions of Coronavirus Ep...
# 22       Early transmission patterns of coronavirus dis...
# 23       HRCT Imaging Features in Representative Import...
# 24       Comprehensive Genomic Characterization Analysi...
# 25       Potential Factors Influencing Repeated SARS Ou...
# 26       Puzzle of highly pathogenic human coronaviruse...
# 27       RETRACTION: Retraction-Chinese medical staff r...
# 28       Critical care response to a hospital outbreak ...
# 29       Effectiveness for the Response to COVID-19: Th...
#                                ...
# 29470                                                  NaN
# 29471                                                  NaN
# 29472                                                  NaN
# 29473                                                  NaN
# 29474                                                  NaN
# 29475                                                  NaN
# 29476                                                  NaN
# 29477                                                  NaN
# 29478                                                  NaN
# 29479                                                  NaN
# 29480                                                  NaN
# 29481                                                  NaN
# 29482                                                  NaN
# 29483                                                  NaN
# 29484                                                  NaN
# 29485                                                  NaN
# 29486                                                  NaN
# 29487                                                  NaN
# 29488                                                  NaN
# 29489                                                  NaN
# 29490                                                  NaN
# 29491                                                  NaN
# 29492                                                  NaN
# 29493                                                  NaN
# 29494                                                  NaN
# 29495                                                  NaN
# 29496                                                  NaN
# 29497                                                  NaN
# 29498                                                  NaN
# 29499                                                  NaN
# Name: title, Length: 29500, dtype: object
#
# doi:
# 0                    10.1007/s00134-020-05985-9
# 1                     10.1038/s41421-020-0147-1
# 2                            10.3390/jcm9020538
# 3                            10.3390/jcm9020575
# 4                    10.1007/s00134-020-05976-w
# 5                     10.1016/j.idm.2020.02.001
# 6                     10.1016/j.idm.2020.02.002
# 7                 10.1016/s2214-109x(20)30065-6
# 8                           10.1093/jtm/taaa030
# 9                         10.1128/mBio.02764-19
# 10                   10.1186/s41256-020-00137-4
# 11       10.2807/1560-7917.ES.2020.25.5.2000080
# 12               10.1093/bioinformatics/btaa145
# 13                     10.3346/jkms.2020.35.e79
# 14                     10.3390/pathogens9020148
# 15                 10.1016/j.eclinm.2020.100289
# 16                 10.1016/j.meegid.2020.104272
# 17                 10.1016/j.micinf.2020.01.004
# 18                    10.1038/s41422-020-0282-0
# 19                          10.1093/jtm/taaa011
# 20                          10.12809/hkmj208375
# 21                 10.20535/ibb.2020.4.1.195074
# 22       10.2807/1560-7917.ES.2020.25.8.2000097
# 23                       10.1093/pcmedi/pbaa004
# 24                     10.3389/fmicb.2019.03036
# 25                       10.3390/ijerph17051633
# 26                   10.1007/s13238-020-00693-y
# 27                10.1016/s2214-109x(20)30076-0
# 28                    10.1186/s13054-020-2786-x
# 29                 10.24171/j.phrp.2020.11.1.01
#                           ...
# 29470       doi.org/10.1101/2020.03.05.20032003
# 29471       doi.org/10.1101/2020.03.05.20032011
# 29472       doi.org/10.1101/2020.03.06.20029793
# 29473       doi.org/10.1101/2020.03.06.20031278
# 29474       doi.org/10.1101/2020.03.06.20031377
# 29475       doi.org/10.1101/2020.03.06.20031856
# 29476       doi.org/10.1101/2020.03.06.20031880
# 29477       doi.org/10.1101/2020.03.06.20031955
# 29478       doi.org/10.1101/2020.03.06.20032144
# 29479       doi.org/10.1101/2020.03.06.20032177
# 29480       doi.org/10.1101/2020.03.06.20032334
# 29481       doi.org/10.1101/2020.03.06.20032417
# 29482       doi.org/10.1101/2020.03.06.20032425
# 29483       doi.org/10.1101/2020.03.07.20031393
# 29484       doi.org/10.1101/2020.03.07.20031575
# 29485       doi.org/10.1101/2020.03.07.20032326
# 29486       doi.org/10.1101/2020.03.07.20032524
# 29487       doi.org/10.1101/2020.03.07.20032573
# 29488       doi.org/10.1101/2020.03.07.20032599
# 29489       doi.org/10.1101/2020.03.07.20032672
# 29490       doi.org/10.1101/2020.03.08.20029710
# 29491       doi.org/10.1101/2020.03.08.20030643
# 29492       doi.org/10.1101/2020.03.08.20031229
# 29493       doi.org/10.1101/2020.03.08.20031658
# 29494       doi.org/10.1101/2020.03.08.20032821
# 29495       doi.org/10.1101/2020.03.08.20032847
# 29496       doi.org/10.1101/2020.03.08.20032854
# 29497       doi.org/10.1101/2020.03.09.20032219
# 29498       doi.org/10.1101/2020.03.09.20033183
# 29499       doi.org/10.1101/2020.03.09.20033217
# Name: doi, Length: 29500, dtype: object
#
# pmcid:0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN
# 6        NaN
# 7        NaN
# 8        NaN
# 9        NaN
# 10       NaN
# 11       NaN
# 12       NaN
# 13       NaN
# 14       NaN
# 15       NaN
# 16       NaN
# 17       NaN
# 18       NaN
# 19       NaN
# 20       NaN
# 21       NaN
# 22       NaN
# 23       NaN
# 24       NaN
# 25       NaN
# 26       NaN
# 27       NaN
# 28       NaN
# 29       NaN
#         ...
# 29470    NaN
# 29471    NaN
# 29472    NaN
# 29473    NaN
# 29474    NaN
# 29475    NaN
# 29476    NaN
# 29477    NaN
# 29478    NaN
# 29479    NaN
# 29480    NaN
# 29481    NaN
# 29482    NaN
# 29483    NaN
# 29484    NaN
# 29485    NaN
# 29486    NaN
# 29487    NaN
# 29488    NaN
# 29489    NaN
# 29490    NaN
# 29491    NaN
# 29492    NaN
# 29493    NaN
# 29494    NaN
# 29495    NaN
# 29496    NaN
# 29497    NaN
# 29498    NaN
# 29499    NaN
# Name: pmcid, Length: 29500, dtype: object - pubmed_id:0        32125455.0
# 1               NaN
# 2               NaN
# 3        32093211.0
# 4        32125453.0
# 5               NaN
# 6               NaN
# 7        32105614.0
# 8               NaN
# 9               NaN
# 10              NaN
# 11              NaN
# 12       32108862.0
# 13              NaN
# 14              NaN
# 15              NaN
# 16              NaN
# 17              NaN
# 18              NaN
# 19              NaN
# 20              NaN
# 21              NaN
# 22              NaN
# 23              NaN
# 24              NaN
# 25              NaN
# 26       32088858.0
# 27       32113504.0
# 28              NaN
# 29              NaN
#             ...
# 29470           NaN
# 29471           NaN
# 29472           NaN
# 29473           NaN
# 29474           NaN
# 29475           NaN
# 29476           NaN
# 29477           NaN
# 29478           NaN
# 29479           NaN
# 29480           NaN
# 29481           NaN
# 29482           NaN
# 29483           NaN
# 29484           NaN
# 29485           NaN
# 29486           NaN
# 29487           NaN
# 29488           NaN
# 29489           NaN
# 29490           NaN
# 29491           NaN
# 29492           NaN
# 29493           NaN
# 29494           NaN
# 29495           NaN
# 29496           NaN
# 29497           NaN
# 29498           NaN
# 29499           NaN
# Name: pubmed_id, Length: 29500, dtype: float64
#
# authors:
# 0        Zhang, Haibo; Penninger, Josef M.; Li, Yimin; ...
# 1        Cao, Yanan; Li, Lin; Feng, Zhimin; Wan, Shengq...
# 2        Linton, M. Natalie; Kobayashi, Tetsuro; Yang, ...
# 3                         Deng, Sheng-Qun; Peng, Hong-Juan
# 4                                               Zhang, Wei
# 5        Tang, Biao; Bragazzi, Nicola Luigi; Li, Qian; ...
# 6        Roosa, K.; Lee, Y.; Luo, R.; Kirpich, A.; Roth...
# 7                                Zeng, Yingchun; Zhen, Yan
# 8                Rocklöv, J.; Sjödin, H.; Wilder-Smith, A.
# 9        Qing, Enya; Hantak, Michael; Perlman, Stanley;...
# 10                                 Chen, Xinguang; Yu, Bin
# 11       Quilty, Billy J; Clifford, Sam; group2, CMMID ...
# 12       Cleemput, S.; Dumon, W.; Fonseca, V.; Karim, W...
# 13       Lim, Jaegyun; Jeon, Seunghyun; Shin, Hyun-Youn...
# 14       Shanmugaraj, Balamurugan; Malla, Ashwini; Phoo...
# 15       Malta, Monica; Rimoin, Anne W.; Strathdee, Ste...
# 16         Fahmi, Muhamad; Kubota, Yukihiko; Ito, Masahiro
# 17                                          Chen, Jieliang
# 18       Wang, Manli; Cao, Ruiyuan; Zhang, Leike; Yang,...
# 19       Bogoch, I. I.; Watts, A.; Thomas-Bachli, A.; H...
# 20                             Hon, K. L.; Leung, K. K. Y.
# 21                                          Nesteruk, Igor
# 22       Okada, Pilailuk; Buathong, Rome; Phuygun, Siri...
# 23       Diao, Kaiyue; Han, Peilun; Pang, Tong; Li, Yua...
# 24       Liui, Junli; Wang, Fangfang; Du, Liuyang; Li, ...
# 25       Sun, Zhong; Thilakavathy, Karuppiah; Kumar, S....
# 26                                   Li, Jing; Liu, Wenjun
# 27                The Editors Of The Lancet Global, Health
# 28                    Liu, Yong; Li, Jinxiu; Feng, Yongwen
# 29                                            Cho, Hae-Wol
#                                ...
# 29470                                                  NaN
# 29471                                                  NaN
# 29472                                                  NaN
# 29473                                                  NaN
# 29474                                                  NaN
# 29475                                                  NaN
# 29476                                                  NaN
# 29477                                                  NaN
# 29478                                                  NaN
# 29479                                                  NaN
# 29480                                                  NaN
# 29481                                                  NaN
# 29482                                                  NaN
# 29483                                                  NaN
# 29484                                                  NaN
# 29485                                                  NaN
# 29486                                                  NaN
# 29487                                                  NaN
# 29488                                                  NaN
# 29489                                                  NaN
# 29490                                                  NaN
# 29491                                                  NaN
# 29492                                                  NaN
# 29493                                                  NaN
# 29494                                                  NaN
# 29495                                                  NaN
# 29496                                                  NaN
# 29497                                                  NaN
# 29498                                                  NaN
# 29499                                                  NaN
# Name: authors, Length: 29500, dtype: object
# \journal:
# 0                                       Intensive Care Med
# 1                                           Cell Discovery
# 2                             Journal of Clinical Medicine
# 3                                               J Clin Med
# 4                                       Intensive Care Med
# 5                             Infectious Disease Modelling
# 6                             Infectious Disease Modelling
# 7                                The Lancet. Global health
# 8                               Journal of Travel Medicine
# 9                                                     mBio
# 10                       Global Health Research and Policy
# 11                                        Eurosurveillance
# 12                        Bioinformatics (Oxford, England)
# 13                       Journal of Korean Medical Science
# 14                                               Pathogens
# 15                                       EClinicalMedicine
# 16                       Infection, Genetics and Evolution
# 17                                  Microbes and Infection
# 18                                           Cell Research
# 19                              Journal of travel medicine
# 20                               Hong Kong Medical Journal
# 21                Innovative Biosystems and Bioengineering
# 22                                        Eurosurveillance
# 23                             Precision Clinical Medicine
# 24                               Frontiers in Microbiology
# 25       International Journal of Environmental Researc...
# 26                                            Protein Cell
# 27                               The Lancet. Global health
# 28                                           Critical Care
# 29           Osong Public Health and Research Perspectives
#                                ...
# 29470                                                  NaN
# 29471                                                  NaN
# 29472                                                  NaN
# 29473                                                  NaN
# 29474                                                  NaN
# 29475                                                  NaN
# 29476                                                  NaN
# 29477                                                  NaN
# 29478                                                  NaN
# 29479                                                  NaN
# 29480                                                  NaN
# 29481                                                  NaN
# 29482                                                  NaN
# 29483                                                  NaN
# 29484                                                  NaN
# 29485                                                  NaN
# 29486                                                  NaN
# 29487                                                  NaN
# 29488                                                  NaN
# 29489                                                  NaN
# 29490                                                  NaN
# 29491                                                  NaN
# 29492                                                  NaN
# 29493                                                  NaN
# 29494                                                  NaN
# 29495                                                  NaN
# 29496                                                  NaN
# 29497                                                  NaN
# 29498                                                  NaN
# 29499                                                  NaN
# Name: journal, Length: 29500, dtype: object - Microsoft Academic Paper ID:0        2.002765e+09
# 1        3.003431e+09
# 2        3.006065e+09
# 3        1.776631e+08
# 4        3.006643e+09
# 5        3.006029e+09
# 6        3.006029e+09
# 7        2.627046e+09
# 8        3.006304e+09
# 9        3.005811e+09
# 10       3.006646e+09
# 11       3.005152e+09
# 12       3.003549e+09
# 13       3.005657e+09
# 14       3.003886e+09
# 15       3.004913e+09
# 16       2.286137e+09
# 17                NaN
# 18       3.005213e+09
# 19       3.004048e+09
# 20       2.029408e+09
# 21       3.006305e+09
# 22       3.005657e+09
# 23       3.006468e+09
# 24       3.003968e+09
# 25       2.615949e+09
# 26       2.766462e+09
# 27       2.794879e+09
# 28       2.537201e+09
# 29       3.005888e+09
#              ...
# 29470             NaN
# 29471             NaN
# 29472             NaN
# 29473             NaN
# 29474             NaN
# 29475             NaN
# 29476             NaN
# 29477             NaN
# 29478             NaN
# 29479             NaN
# 29480             NaN
# 29481             NaN
# 29482             NaN
# 29483             NaN
# 29484             NaN
# 29485             NaN
# 29486             NaN
# 29487             NaN
# 29488             NaN
# 29489             NaN
# 29490             NaN
# 29491             NaN
# 29492             NaN
# 29493             NaN
# 29494             NaN
# 29495             NaN
# 29496             NaN
# 29497             NaN
# 29498             NaN
# 29499             NaN
# Name: Microsoft Academic Paper ID, Length: 29500, dtype: float64 - WHO #Covidence: 0        #3252
# 1        #1861
# 2        #1043
# 3        #1999
# 4        #3242
# 5         #729
# 6         #865
# 7        #5386
# 8        #2926
# 9        #2427
# 10       #5595
# 11        #682
# 12       #2776
# 13       #3770
# 14       #1502
# 15       #3333
# 16       #4581
# 17        #236
# 18        #205
# 19        #102
# 20       #3395
# 21       #1218
# 22       #2582
# 23        #781
# 24       #5462
# 25       #3296
# 26       #1815
# 27       #5486
# 28       #1225
# 29       #2662
#          ...
# 29470      NaN
# 29471      NaN
# 29472      NaN
# 29473      NaN
# 29474      NaN
# 29475      NaN
# 29476      NaN
# 29477      NaN
# 29478      NaN
# 29479      NaN
# 29480      NaN
# 29481      NaN
# 29482      NaN
# 29483      NaN
# 29484      NaN
# 29485      NaN
# 29486      NaN
# 29487      NaN
# 29488      NaN
# 29489      NaN
# 29490      NaN
# 29491      NaN
# 29492      NaN
# 29493      NaN
# 29494      NaN
# 29495      NaN
# 29496      NaN
# 29497      NaN
# 29498      NaN
# 29499      NaN
# Name: WHO #Covidence, Length: 29500, dtype: object

# %% [markdown]
# ---

# %% [markdown]
# # Xviv Pipeline

# %% [markdown]
# ### Loading json file function

# %%
import os
import json

def load_xviv(path):
    
    input_file = os.path.join(path)
    with open(input_file) as json_file:
        data = json.load(json_file)
        
        print("PAPER_ID: {}\n\nTITLE:\n{}".format(data['paper_id'],
                                                  data['metadata']['title']))
    
        name_fst = (item['authors']['first'] for item in data['metadata'])
        print("{}".format(name_fst))

# %%
import os
import json

def load_xviv(path):
    
    input_file = os.path.join(path)
    with open(input_file) as json_file:
        data = json.load(json_file)
        
        paper_id = data['paper_id']
        text = data['body_text'][:]
        
        return paper_id, text

# %%
def print_it(doc):
    print("PAPER_ID: {}\n\nTITLE:\n{} \n\TEXT:\n{}".format(doc), (doc))

# %%
doc = load_xviv('2020-03-13/biorxiv_medrxiv/biorxiv_medrxiv/0015023cc06b5362d332b3baf348d11567ca2fbb.json')
print_it(doc)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-22-f2980974d038> in <module>
#       1 doc = load_xviv('2020-03-13/biorxiv_medrxiv/biorxiv_medrxiv/0015023cc06b5362d332b3baf348d11567ca2fbb.json')
# ----> 2 print_it(doc)
#
# <ipython-input-21-b3b52bbb610d> in print_it(doc)
#       1 def print_it(doc):
# ----> 2     print("PAPER_ID: {}\n\nTITLE:\n{}".format(doc), (doc))
#
# IndexError: tuple index out of range

# %% [markdown]
# generator = ( item['value'] for item in test_data )
#
# ...
#
# for i in generator:
#     do_something(i)

# %% [markdown]
# ### Retrieve text document

# %%
load_xviv('2020-03-13/biorxiv_medrxiv/biorxiv_medrxiv/0015023cc06b5362d332b3baf348d11567ca2fbb.json')
# Out:
# 0015023cc06b5362d332b3baf348d11567ca2fbb

# %%
\n\nAUTHORS:\n{} {} \n\nTEXT:\n{}
data['metadata']['authors'][0]['first'],
                                                                         data['metadata']['authors'][0]['last'],
                                                                         data['body_text'][:]))

# %% [markdown]
# ---

# %% [markdown]
# # Phrase Matching

# %% [markdown]
# ### Defining Patterns

# %%
m_tool.add('Pulmonary', factor[0])

# %%
factor = {}
for i in processed_docs[:8]:
    vocab[i] = set(i)
    factor.append(vocab)

for i in range(8):
    print(len(factor[i]), factor[i])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-7c36c3c3f5fa> in <module>
#       1 factor = {}
#       2 for i in processed_docs[:8]:
# ----> 3     vocab[i] = set(i)
#       4     factor.append(vocab)
#       5
#
# TypeError: 'set' object does not support item assignment

# %%
from sklearn.feature_extraction.text import CountVectorizer
vec = CountVectorizer(binary=True)
for i in range(8):
    vec.fit(factor[i])
    print([w for w in sorted(vec.vocabulary_.keys())])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-5a61ec7f459d> in <module>
#       2 vec = CountVectorizer(binary=True)
#       3 for i in range(8):
# ----> 4     vec.fit(factor[i])
#       5     print([w for w in sorted(vec.vocabulary_.keys())])
#
# KeyError: 0

# %% [markdown]
# # Sentences coordinates >> abstract
